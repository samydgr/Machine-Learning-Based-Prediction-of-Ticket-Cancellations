# %% [markdown]
# <h1 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# Machine Learning-Based Prediction of Ticket Cancellations
# </font>
# </h1>

# %% [markdown]
# <h2 align="left" style="line-height:200%;font-family:vazir;font-family:Arial;color:#0099cc">
# <font face="Arial" color="#0099cc">
# Introduction and Problem Statement
# </font>
# </h2>
#
#
# <h4 align="left">
# <font face="Arial" >
# In this project, we aim to predict whether users will cancel their tickets or not. For each cancellation, MrBilit must pay a penalty fee to the transportation company. Therefore, canceled tickets mean imposing costs on the company. Therefore, identifying tickets that are likely to be canceled is a great help in managing the company's risk.
# </font>
# </h4>

# %% [markdown]
# <h2 align="left" style="line-height:200%;font-family:vazir;font-family:Arial;color:#0099cc">
# <font face="Arial" color="#0099cc">
# Importing Essential Libraries
# </font>
# </h2>

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import f1_score, classification_report, confusion_matrix

# %% [markdown]
# <h2 align="left" style="line-height:200%;font-family:vazir;font-family:Arial;color:#0099cc">
# <font face="Arial" color="#0099cc">
# Reading the dataset and splitting it into training and testing sets.
# </font>
# </h2>

# %%
train_data = pd.read_csv('../data/train_data.csv' , parse_dates = ['Created' , 'DepartureTime'] )
train_data
# Out:
#                        Created               CancelTime       DepartureTime  \
# 0      2022-07-26 13:33:20.457                      NaN 2022-07-26 16:30:00
# 1      2022-10-27 23:07:01.837  2022-10-27 23:26:39.070 2022-10-29 09:45:00
# 2      2022-09-12 11:01:13.607                      NaN 2022-10-03 18:35:00
# 3      2022-08-08 17:43:35.840                      NaN 2022-08-08 22:30:00
# 4      2022-11-01 15:12:56.823                      NaN 2022-11-03 11:30:00
# ...                        ...                      ...                 ...
# 101012 2022-10-27 21:41:35.803                      NaN 2022-11-05 20:15:00
# 101013 2022-09-24 15:51:11.993                      NaN 2022-10-21 09:15:00
# 101014 2022-08-12 13:46:20.480                      NaN 2022-08-12 23:59:00
# 101015 2022-06-20 15:15:37.780                      NaN 2022-06-25 10:10:00
# 101016 2022-07-25 00:25:14.170                      NaN 2022-07-25 21:00:00
#
#           BillID   TicketID  ReserveStatus    UserID   Male       Price  \
# 0       38428546  7445571.0              3       NaN   True   1180000.0
# 1       39768762  7762719.0              5       NaN  False   1050000.0
# 2       39128001  2327596.0              5  800398.0  False   4674000.0
# 3       38606546  7495440.0              3       NaN   True   1200000.0
# 4       39822185  2356902.0              5       NaN   True   6222000.0
# ...          ...        ...            ...       ...    ...         ...
# 101012  39767774  3082282.0              2       NaN  False   7200000.0
# 101013  39319207  3026516.0              2  151423.0  False   4292000.0
# 101014  38653461  7508988.0              3       NaN   True   1320000.0
# 101015  37880627  1057205.0              5  641744.0   True  13000000.0
# 101016  38408696  7439771.0              3  857274.0   True   2150000.0
#
#         CouponDiscount  ... Domestic  \
# 0                  0.0  ...        1
# 1                  0.0  ...        1
# 2                  0.0  ...        1
# 3                  0.0  ...        1
# 4                  0.0  ...        1
# ...                ...  ...      ...
# 101012             0.0  ...        1
# 101013             0.0  ...        1
# 101014             0.0  ...        1
# 101015             0.0  ...        1
# 101016             0.0  ...        1
#
#                                               VehicleType  VehicleClass  \
# 0       VIPمانیتوردار-شارژراختصاصی تخت شو مارال (جدید)...          True
# 1                                           classicus 2+2          True
# 2                                                فوکر 100         False
# 3                 VIPدرسا+مانیتوردار+شارژراختصاصی+پذیرایی          True
# 4                                                     NaN         False
# ...                                                   ...           ...
# 101012                            5ستاره بيزينس سلامت فدك           NaN
# 101013                                   4ستاره4تخته سپهر           NaN
# 101014  VIP 2+1  / مانیتوردار / سیستم تهویه مطبوع / تخ...          True
# 101015                                                NaN         False
# 101016                                        MAN VIP 2+1          True
#
#        TripReason Vehicle Cancel HashPassportNumber_p  \
# 0            Work     Bus      0                  NaN
# 1             Int     Bus      1                  NaN
# 2             Int   Plane      0                  NaN
# 3            Work     Bus      0                  NaN
# 4            Work   Plane      0                  NaN
# ...           ...     ...    ...                  ...
# 101012        Int   Train      0                  NaN
# 101013        Int   Train      0                  NaN
# 101014        Int     Bus      0                  NaN
# 101015       Work   Plane      0                  NaN
# 101016       Work     Bus      0                  NaN
#
#                                                 HashEmail   BuyerMobile  \
# 0                                                     NaN  302222356019
# 1                                                     NaN  900764168521
# 2       1c44d7a76b52341fa12dcfa993138576befcc9ebf01d14...  749804783291
# 3                                                     NaN  781396205677
# 4       bb38b345aec02255e31d178492907175c5984f2a1f5b59...  524576220177
# ...                                                   ...           ...
# 101012                                                NaN  395081863564
# 101013  3f28ed65a16d629747e4d27fab100b2b082fcbdf7ec831...  130026405332
# 101014                                                NaN  784949357488
# 101015  750690ca99468f159eff6ad928cec4339b089af8c2e6dc...  766602541733
# 101016                                                NaN  899439800471
#
#        NationalCode
# 0         330024570
# 1         995520696
# 2         979382950
# 3         911237229
# 4         727496008
# ...             ...
# 101012    789320493
# 101013    866503410
# 101014    881677039
# 101015    403505466
# 101016    593217954
#
# [101017 rows x 22 columns]

# %%
train_data, test_data = train_test_split(train_data, test_size=0.1, random_state=5)

# %% [markdown]
# <h2 align="left" style="line-height:200%;font-family:vazir;font-family:Arial;color:#0099cc">
# <font face="Arial" color="#0099cc">
# Let's begin by exploring and preprocessing the data.
# </font>
# </h2>

# %% [markdown]
# <h3 style="text-align: left; font-family: Arial;">
#   <strong>We will take a general overview of the features and examine the data status.</strong>
# </h3>

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90915 entries, 81173 to 35683
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Created               90915 non-null  datetime64[ns]
#  1   CancelTime            13744 non-null  object
#  2   DepartureTime         90915 non-null  datetime64[ns]
#  3   BillID                90915 non-null  int64
#  4   TicketID              90915 non-null  float64
#  5   ReserveStatus         90915 non-null  int64
#  6   UserID                38243 non-null  float64
#  7   Male                  90915 non-null  bool
#  8   Price                 90915 non-null  float64
#  9   CouponDiscount        90915 non-null  float64
#  10  From                  90915 non-null  object
#  11  To                    90915 non-null  object
#  12  Domestic              90915 non-null  int64
#  13  VehicleType           83999 non-null  object
#  14  VehicleClass          56436 non-null  object
#  15  TripReason            90915 non-null  object
#  16  Vehicle               90915 non-null  object
#  17  Cancel                90915 non-null  int64
#  18  HashPassportNumber_p  773 non-null    object
#  19  HashEmail             38759 non-null  object
#  20  BuyerMobile           90915 non-null  int64
#  21  NationalCode          90915 non-null  int64
# dtypes: bool(1), datetime64[ns](2), float64(4), int64(6), object(9)
# memory usage: 15.3+ MB

# %% [markdown]
# <h3 style="text-align: left; font-family: Arial;">
#   <strong>Let's remove the 'CancelTime' feature as it only reflects past cancellations and doesn't predict future ones. We'll also focus on identifying features that indicate potential cancellations before they happen.</strong>
# </h3>

# %%
train_data.drop('CancelTime', axis=1, inplace=True)

# %% [markdown]
# <h3 style="text-align: left; font-family: Arial;">
#   <strong>Let's remove the 'CancelTime' feature as it only reflects past cancellations and doesn't predict future ones. We'll also focus on identifying features that indicate potential cancellations before they happen.</strong>
# </h3>

# %%
train_data.describe()
# Out:
#              BillID      TicketID  ReserveStatus         UserID         Price  \
# count  9.091500e+04  9.091500e+04   90915.000000   38243.000000  9.091500e+04
# mean   3.832618e+07  4.934980e+06       3.163328  578260.807050  3.216420e+06
# std    1.099443e+06  2.411379e+06       1.077265  273642.611185  7.022877e+06
# min    3.591084e+07  1.015844e+06       2.000000    7958.000000 -1.514000e+06
# 25%    3.743548e+07  2.847476e+06       2.000000  338141.000000  1.080000e+06
# 50%    3.855511e+07  3.078578e+06       3.000000  613090.000000  1.690000e+06
# 75%    3.931258e+07  7.431198e+06       4.000000  821860.000000  3.068500e+06
# max    3.984016e+07  7.782861e+06       5.000000  983278.000000  3.837646e+08
#
#        CouponDiscount      Domestic        Cancel   BuyerMobile  NationalCode
# count    9.091500e+04  90915.000000  90915.000000  9.091500e+04  9.091500e+04
# mean     5.003949e+03      0.992092      0.151097  5.038735e+11  1.588451e+14
# std      7.331650e+04      0.088578      0.358146  2.876358e+11  1.021546e+16
# min      0.000000e+00      0.000000      0.000000  1.170136e+07  2.900000e+02
# 25%      0.000000e+00      1.000000      0.000000  2.580028e+11  2.500405e+08
# 50%      0.000000e+00      1.000000      0.000000  5.052501e+11  5.017679e+08
# 75%      0.000000e+00      1.000000      0.000000  7.510403e+11  7.502481e+08
# max      1.443333e+07      1.000000      1.000000  9.999831e+11  9.790847e+17

# %%
negative_zero_prices = train_data[train_data['Price'] <= 0]
negative_zero_prices
# Out:
#                       Created       DepartureTime    BillID   TicketID  \
# 45449 2022-03-08 08:45:13.923 2022-03-10 19:25:00  36359345  2686190.0
# 65809 2022-08-27 19:12:08.697 2022-09-06 01:00:00  38845766  2976732.0
#
#        ReserveStatus    UserID  Male      Price  CouponDiscount   From  ...  \
# 45449              4  328142.0  True -1514000.0             0.0  تهران  ...
# 65809              4  887350.0  True        0.0             0.0   مشهد  ...
#
#       Domestic              VehicleType VehicleClass TripReason Vehicle  \
# 45449        1  5 ستاره نور ( اكونومي )          NaN        Int   Train
# 65809        1     4 ستاره 4 تخته كرخه           NaN        Int   Train
#
#       Cancel  HashPassportNumber_p  \
# 45449      1                   NaN
# 65809      1                   NaN
#
#                                                HashEmail   BuyerMobile  \
# 45449  887c2c48e3dfb21b2b813a1ae114fb9f3a92cb0699caa1...  368964586670
# 65809  a3452cefe95858f0d38b8e83f252c06f988f65016d8880...  317469453449
#
#        NationalCode
# 45449     285250708
# 65809     170427200
#
# [2 rows x 21 columns]

# %%
train_data = train_data[train_data['Price'] > 0]

# %% [markdown]
# <h4 style="text-align: left; font-family: Arial;">
#   <strong>Encode the "TripReason","Male" feature into a binary format. </strong>
# </h4>

# %%
train_data['TripReason'] = train_data['TripReason'].map({'Int' : 0,'Work':1})
test_data['TripReason'] = test_data['TripReason'].map({'Int' : 0,'Work':1})
train_data['Male'] = train_data.Male.map({True : 1,False:0})
test_data['Male'] = test_data.Male.map({True : 1,False:0})

# %% [markdown]
# <h3 style="text-align: left; font-family: Arial;">
# Visualizing the categorical variable 'VehicleClass' revealed high cancellation rates for trains, while international flights showed a lower cancellation rate.
# </h3>

# %%
import matplotlib.pyplot as plt
cancel_rates = train_data.groupby('Vehicle')['Cancel'].mean()
plt.figure(figsize=(10, 6))
cancel_rates.plot(kind='bar', color='skyblue')
plt.title('Cancellation Rate by Vehicle Class')
plt.xlabel('Vehicle Class')
plt.ylabel('Cancellation Rate')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h4 style="text-align: left; font-family: Arial; ">
# The 'VehicleClass' feature may not be very informative.
# </h4>

# %%
cancel_rates = train_data.groupby('VehicleClass')['Cancel'].mean()
plt.figure(figsize=(10, 6))
cancel_rates.plot(kind='bar', color='skyblue')
plt.title('Cancellation Rate by Vehicle Class')
plt.xlabel('Vehicle Class')
plt.ylabel('Cancellation Rate')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h4 style="text-align: left; font-family: Arial; color: #3399ff;">
# Visualize the train data correlations with a correlation matrix.
# </h4>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
correlation = train_data.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation, annot=True)
plt.title("Correlation Matrix for Train Data")
plt.show()

# %% [markdown]
# <h4 style="text-align: left; font-family: Arial; color: #3399ff;">
# A potentially significant feature is the time difference between 'DepartureTime' and 'CreatedTime'. This could indicate factors like booking lead time or last-minute cancellations.
# </h4>

# %%
train_data['Created'] = pd.to_datetime(train_data['Created'])
train_data['DepartureTime'] = pd.to_datetime(train_data['DepartureTime'])
train_data['TimeDifference_minutes'] = round((train_data['DepartureTime'] - train_data['Created']).dt.total_seconds() / 60)
train_data
# Out:
#                       Created       DepartureTime    BillID   TicketID  \
# 81173 2022-08-21 11:03:33.883 2022-08-27 18:15:00  38755446  7537774.0
# 18754 2022-06-16 15:20:02.340 2022-09-01 11:30:00  37819689  2847850.0
# 93161 2022-10-18 12:08:25.060 2022-10-21 23:57:00  39652563  7729861.0
# 85171 2022-09-25 09:33:34.800 2022-10-01 08:00:00  39331325  7645220.0
# 80798 2022-09-10 10:29:01.930 2022-09-14 18:10:00  39094093  2999353.0
# ...                       ...                 ...       ...        ...
# 59465 2022-07-26 15:23:32.713 2022-08-06 21:05:00  38430226  2919186.0
# 5520  2022-05-02 22:26:40.300 2022-05-03 08:30:00  37162748  7099241.0
# 20463 2022-03-26 11:26:21.690 2022-03-29 22:45:00  36661650  6970924.0
# 18638 2022-03-12 09:36:40.340 2022-03-12 10:35:00  36417784  6899861.0
# 35683 2022-06-07 16:10:23.977 2022-06-10 16:45:00  37681954  7238177.0
#
#        ReserveStatus    UserID  Male      Price  CouponDiscount       From  \
# 81173              3  747021.0     1  2640000.0             0.0        یزد
# 18754              2       NaN     1  3553500.0             0.0       مشهد
# 93161              3       NaN     1  1220000.0             0.0  خمینی شهر
# 85171              3  959914.0     0   790000.0             0.0      تهران
# 80798              2  564864.0     1  1920500.0             0.0      تهران
# ...              ...       ...   ...        ...             ...        ...
# 59465              4       NaN     0  2810500.0             0.0       مشهد
# 5520               3       NaN     1   850000.0             0.0   بندرعباس
# 20463              5       NaN     1   680000.0             0.0       بابل
# 18638              3       NaN     0   250000.0             0.0      تبریز
# 35683              5  159235.0     1  1350000.0             0.0      رامسر
#
#        ...                               VehicleType  VehicleClass TripReason  \
# 81173  ...  مارالVIP تخت شو 25 نفره با شارژر اختصاصی          True          0
# 18754  ...                      4 ستاره 4 تخته غزال            NaN          0
# 93161  ...                          مارال مانیتوردار          True          1
# 85171  ...                             25 نفره (VIP)          True          1
# 80798  ...                       3 ستاره 6 تخته كوير           NaN          1
# ...    ...                                       ...           ...        ...
# 59465  ...                      4 ستاره 4 تخته غزال            NaN          0
# 5520   ...                                   اسکانیا          True          1
# 20463  ...                              سوپر ویژه 44         False          0
# 18638  ...        BENZ C457 2+2  / سیستم تهویه مطبوع         False          1
# 35683  ...             ۲۵ نفره تخت شو از مسیرازادراه          True          0
#
#       Vehicle  Cancel HashPassportNumber_p  \
# 81173     Bus       0                  NaN
# 18754   Train       0                  NaN
# 93161     Bus       0                  NaN
# 85171     Bus       0                  NaN
# 80798   Train       0                  NaN
# ...       ...     ...                  ...
# 59465   Train       1                  NaN
# 5520      Bus       0                  NaN
# 20463     Bus       1                  NaN
# 18638     Bus       0                  NaN
# 35683     Bus       1                  NaN
#
#                                                HashEmail   BuyerMobile  \
# 81173                                                NaN  117595987163
# 18754                                                NaN  258774611239
# 93161                                                NaN  599305991496
# 85171  3c3d49777a1141ba6f91f68a6117f7687c84092298b262...  774751208362
# 80798  c6528a5b6e3a964b953fcd192e2b49e33ae41197582f2f...  780404536873
# ...                                                  ...           ...
# 59465                                                NaN  224948328416
# 5520                                                 NaN   15096748550
# 20463                                                NaN  867895973998
# 18638                                                NaN  837522176071
# 35683  aff4b8e4c336b18ef2133b3882739e3264bc0dcdbe833e...  737013908719
#
#       NationalCode  TimeDifference_minutes
# 81173    193305148                  9071.0
# 18754    485804600                110650.0
# 93161    760677022                  5029.0
# 85171    915339530                  8546.0
# 80798    798266396                  6221.0
# ...            ...                     ...
# 59465     92231896                 16181.0
# 5520     288430549                   603.0
# 20463     62486610                  4999.0
# 18638    367037161                    58.0
# 35683    785710990                  4355.0
#
# [90913 rows x 22 columns]

# %%
test_data['Created'] = pd.to_datetime(test_data['Created'])
test_data['DepartureTime'] = pd.to_datetime(test_data['DepartureTime'])
test_data['TimeDifference_minutes'] = round((test_data['DepartureTime'] - test_data['Created']).dt.total_seconds() / 60)
test_data
# Out:
#                       Created               CancelTime       DepartureTime  \
# 9369  2022-07-08 00:29:44.210                      NaN 2022-07-19 17:00:00
# 91940 2022-10-08 16:10:04.747                      NaN 2022-10-09 23:00:00
# 95628 2022-07-23 20:16:20.280                      NaN 2022-08-03 09:26:00
# 30554 2022-10-30 00:34:28.977  2022-10-31 07:40:52.263 2022-10-30 11:00:00
# 49628 2022-03-13 18:09:33.590                      NaN 2022-03-24 23:00:00
# ...                       ...                      ...                 ...
# 84241 2022-03-09 18:20:14.183  2022-03-10 16:54:27.160 2022-03-10 21:45:00
# 6862  2022-09-15 18:26:10.930                      NaN 2022-09-29 05:00:00
# 43528 2022-09-13 20:27:55.253                      NaN 2022-09-13 23:37:00
# 66032 2022-09-23 06:53:41.313                      NaN 2022-09-25 22:15:00
# 32852 2022-10-06 11:26:34.403                      NaN 2022-10-07 00:40:00
#
#          BillID   TicketID  ReserveStatus    UserID  Male       Price  \
# 9369   38162117  7368667.0              3  442001.0     1   2300000.0
# 91940  39539931  7699740.0              3       NaN     1   1260000.0
# 95628  38392048  2914600.0              2  493773.0     1   1297500.0
# 30554  39791602  2355114.0              5       NaN     1  13500000.0
# 49628  36448460  6909235.0              3  695075.0     1   1300000.0
# ...         ...        ...            ...       ...   ...         ...
# 84241  36383567  2687995.0              4  736289.0     0    914000.0
# 6862   39179015  7615981.0              3       NaN     0    980000.0
# 43528  39150605  3006594.0              2  307986.0     1    687500.0
# 66032  39292548  2333154.0              5  350355.0     1   6963000.0
# 32852  39510583  3049448.0              2  797739.0     1   2150000.0
#
#        CouponDiscount  ...                                        VehicleType  \
# 9369              0.0  ...                    مارال زیرپادارتخت شوشارژردارVIP
# 91940             0.0  ...  غزال VIP تخت شو همراه با صندلی های مانیتور دار...
# 95628             0.0  ...                                4 ستاره اتوبوسي صبا
# 30554             0.0  ...                                                NaN
# 49628             0.0  ...                                   درسا 25 نفره VIP
# ...               ...  ...                                                ...
# 84241             0.0  ...                              4 ستاره اتوبوسي نگين
# 6862              0.0  ...                                  مارال 25 نفره VIP
# 43528             0.0  ...                                3 ستاره 4 تخته سهند
# 66032             0.0  ...                                                NaN
# 32852             0.0  ...                                  3ستاره6تخته پارسي
#
#       VehicleClass  TripReason Vehicle Cancel  HashPassportNumber_p  \
# 9369          True           1     Bus      0                   NaN
# 91940         True           1     Bus      0                   NaN
# 95628          NaN           1   Train      0                   NaN
# 30554        False           1   Plane      1                   NaN
# 49628         True           0     Bus      0                   NaN
# ...            ...         ...     ...    ...                   ...
# 84241          NaN           1   Train      1                   NaN
# 6862          True           1     Bus      0                   NaN
# 43528          NaN           1   Train      0                   NaN
# 66032        False           1   Plane      0                   NaN
# 32852          NaN           1   Train      0                   NaN
#
#                                                HashEmail   BuyerMobile  \
# 9369   e6eab6bb7780ff4c0234f02df05351c75eb755286c24d7...  385294105086
# 91940                                                NaN   96361199492
# 95628  8db8bf3016f9e4ed90085abbacbd0237619eeeea76986f...  102600981920
# 30554  aec2c2f4883ea380a51cf3d9bd3b8205624e0e526c0f40...   49722301534
# 49628                                                NaN  915658832938
# ...                                                  ...           ...
# 84241  1fb2e48bc76dd00310763b9a1c3b9cdf0e66a135a1a0a5...  209891112240
# 6862                                                 NaN  942307841473
# 43528                                                NaN  349419049796
# 66032  040f5c25a8e1fa77bc104412688195977ee0059b4d6b46...  541303769274
# 32852  3468cd568509ceff8ba1750686ab37f313aa1326285b3b...  884621552312
#
#       NationalCode TimeDifference_minutes
# 9369     913574581                16830.0
# 91940    422912021                 1850.0
# 95628    213748194                15190.0
# 30554    262657159                  626.0
# 49628    854700791                16130.0
# ...            ...                    ...
# 84241    419713269                 1645.0
# 6862     476184854                19354.0
# 43528    298411066                  189.0
# 66032    711371472                 3801.0
# 32852    201546332                  793.0
#
# [10102 rows x 23 columns]

# %%
def discount_calculator(df) :
    thereshold = 10000
    df['CouponDiscount'] = df['CouponDiscount'].apply(lambda x : 'Above_10000' if x>=thereshold else('no_discount' if x==0 else 'Above_100000'))
    return df
trian_data = discount_calculator(train_data)
test_data = discount_calculator(test_data)

# %%
train_data['CouponDiscount'].value_counts()
# Out:
# no_discount     85483
# Above_100000     5430
# Name: CouponDiscount, dtype: int64

# %% [markdown]
# <h4 style="text-align: left; font-family: Arial; color: #3399ff;">
#   Three Steps to Transform Destination Cities
# </h4>
# <h4 style="text-align: left; font-family: Arial; color: #3399ff;">
#   1. Unify Locations:
# </h4>
# <p>
#   We gather all destinations (cities) from both the training and testing data into a single list. This ensures that all cities, regardless of whether they appear in the training or testing set, are encoded consistently using the same numerical labels.
# </p>
#
# <h4 style="text-align: left; font-family: Arial; color: #3399ff;">
#   2. Encode Uniques:
# </h4>
# <p>
#   We identify all unique city names (e.g., "New York", "London"). Each unique city is assigned a unique numerical label, starting from 0. This process creates a mapping between city names and their corresponding numerical representations.
# </p>
#
# <h4 style="text-align: left; font-family: Arial; color: #3399ff;">
#   3. Replace Text with Numbers:
# </h4>
# <p>
#   We replace the original text destinations ("From" and "To") in both the training and testing data with their corresponding numerical labels obtained in step 2. By doing this, we convert the categorical data (city names) into a format suitable for machine learning models that typically work best with numerical features.
# </p>

# %%
all_locations = np.concatenate([train_data['From'], train_data['To'], test_data['From'], test_data['To']])
unique_locations = np.unique(all_locations)
label_encoder_loc = LabelEncoder()
label_encoder_loc .fit(unique_locations)
train_data['From'] = label_encoder_loc .transform(train_data['From'])
train_data['To'] = label_encoder_loc .transform(train_data['To'])
test_data['From'] = label_encoder_loc .transform(test_data['From'])
test_data['To'] = label_encoder_loc .transform(test_data['To'])

# %% [markdown]
# <h4 style="text-align: left; font-family: Arial; color: #3399ff;">
# Impute missing values in the 'VehicleClass' column.
# </h4>

# %%
p_class = train_data.dropna(subset=['Domestic', 'Price', 'CouponDiscount', 'VehicleClass','ReserveStatus'])
p_class = p_class[['Domestic', 'Price', 'CouponDiscount', 'VehicleClass','ReserveStatus']]
p_test = train_data[train_data['VehicleClass'].isnull()]

# %%
p_class.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56436 entries, 81173 to 35683
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Domestic        56436 non-null  int64
#  1   Price           56436 non-null  float64
#  2   CouponDiscount  56436 non-null  object
#  3   VehicleClass    56436 non-null  object
#  4   ReserveStatus   56436 non-null  int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 2.6+ MB

# %%
p_class['VehicleClass'] = p_class['VehicleClass'].astype(int)
print(p_class)
# Out:
#        Domestic      Price CouponDiscount  VehicleClass  ReserveStatus
# 81173         1  2640000.0    no_discount             1              3
# 93161         1  1220000.0    no_discount             1              3
# 85171         1   790000.0    no_discount             1              3
# 43342         1  2600000.0    no_discount             1              5
# 91935         1  3320000.0    no_discount             1              3
# ...         ...        ...            ...           ...            ...
# 33800         1  9908000.0    no_discount             0              5
# 5520          1   850000.0    no_discount             1              3
# 20463         1   680000.0    no_discount             0              5
# 18638         1   250000.0    no_discount             0              3
# 35683         1  1350000.0    no_discount             1              5
#
# [56436 rows x 5 columns]

# %%
null_counts = p_class.isnull().sum()
columns_with_null = null_counts[null_counts > 0]
if not columns_with_null.empty:
    print("Columns with null values and their counts:")
    print(columns_with_null)
else:
    print("There are no null values in any column.")
# Out:
# There are no null values in any column.

# %%
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

X_train, X_val, y_train, y_val = train_test_split(p_class[['Domestic', 'Price','ReserveStatus']],
                                                  p_class['VehicleClass'],
                                                  test_size=0.2,
                                                  random_state=42)
param_grid = {
    'learning_rate': [0.001, 0.01, 0.1, 0.3],
    'max_depth': [3, 5, 8, 12, 15],
    'n_estimators': [100, 250, 500, 1000]
}
xgb_clf = XGBClassifier()
grid_search = GridSearchCV(estimator=xgb_clf, param_grid=param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train)
best_model = grid_search.best_estimator_
predicted_vehicle_class_val = best_model.predict(X_val)
classification_rep_val = classification_report(y_val, predicted_vehicle_class_val)
X_test = p_test[['Domestic', 'Price','ReserveStatus']]
predicted_vehicle_class = best_model.predict(X_test)
p_test['VehicleClass'] = predicted_vehicle_class

print("Classification report for validation set:\n", classification_rep_val)
# Out:
# Classification report for validation set:
#                precision    recall  f1-score   support
#
#            0       0.97      0.86      0.91      2840
#            1       0.95      0.99      0.97      8448
#
#     accuracy                           0.96     11288
#    macro avg       0.96      0.92      0.94     11288
# weighted avg       0.96      0.96      0.96     11288
# C:\Users\Asus\AppData\Local\Temp\ipykernel_16648\4100325583.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_test['VehicleClass'] = predicted_vehicle_class

# %%
best_params = grid_search.best_params_
print("Best model parameters:", best_params)
# Out:
# Best model parameters: {'learning_rate': 0.3, 'max_depth': 8, 'n_estimators': 500}

# %%
p_test.VehicleClass.value_counts()
# Out:
# 1    28099
# 0     6378
# Name: VehicleClass, dtype: int64

# %%
train_data.loc[train_data['VehicleClass'].isnull(), 'VehicleClass'] = p_test['VehicleClass'].values


if train_data['VehicleClass'].isnull().any():
    print("There are still null values in train_data['VehicleClass'].")
else:
    print("All null values in train_data['VehicleClass'] have been filled.")
# Out:
# All null values in train_data['VehicleClass'] have been filled.

# %%
train_data['VehicleClass'].value_counts()
# Out:
# True     69813
# False    21100
# Name: VehicleClass, dtype: int64

# %%
train_data['VehicleClass'] = train_data['VehicleClass'].map({True: 1, False: 0})

# %%
X_test_null = test_data[test_data['VehicleClass'].isnull()][['Domestic', 'Price','ReserveStatus']]
predicted_vehicle_class = best_model.predict(X_test_null)
test_data.loc[test_data['VehicleClass'].isnull(), 'VehicleClass'] = predicted_vehicle_class

# %%
test_data['VehicleClass'] = test_data['VehicleClass'].map({True: 1, False: 0})

# %% [markdown]
# <h4 style="text-align: left; font-family: Arial; color: #3399ff;">
# Our analysis suggests that the 'VehicleClass' feature might not be as informative as we initially expected.
# </h4>

# %%
cancel_rates = train_data.groupby('VehicleClass')['Cancel'].mean()
plt.figure(figsize=(10, 6))
cancel_rates.plot(kind='bar', color='skyblue')
plt.title('Cancellation Rate by Vehicle Class')
plt.xlabel('Vehicle Class')
plt.ylabel('Cancellation Rate')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h4 style="text-align: left; font-family: Arial; color: #3399ff;">
# Based on our analysis, we can select the most relevant features to improve the final prediction.
# </h4>

# %%
test_X = test_data[['ReserveStatus','Male','Price','CouponDiscount','Domestic','Vehicle','VehicleClass','From','To','TimeDifference_minutes','TripReason']]
X = train_data[['ReserveStatus','Male','Price','CouponDiscount','Domestic','Vehicle','VehicleClass','From','To','TimeDifference_minutes','TripReason']]
y = train_data['Cancel']
y_test = test_data['Cancel']

# %%
label_encoder_cop = LabelEncoder()
X['CouponDiscount'] =  label_encoder_cop.fit_transform(X['CouponDiscount'])
test_X['CouponDiscount'] =  label_encoder_cop.transform(test_X['CouponDiscount'])
label_encoder_car = LabelEncoder()
X['Vehicle'] = label_encoder_car.fit_transform(X['Vehicle'])
test_X['Vehicle'] = label_encoder_car.transform(test_X['Vehicle'])
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_16648\2348801866.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['CouponDiscount'] =  label_encoder_cop.fit_transform(X['CouponDiscount'])
# C:\Users\Asus\AppData\Local\Temp\ipykernel_16648\2348801866.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_X['CouponDiscount'] =  label_encoder_cop.transform(test_X['CouponDiscount'])
# C:\Users\Asus\AppData\Local\Temp\ipykernel_16648\2348801866.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Vehicle'] = label_encoder_car.fit_transform(X['Vehicle'])
# C:\Users\Asus\AppData\Local\Temp\ipykernel_16648\2348801866.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_X['Vehicle'] = label_encoder_car.transform(test_X['Vehicle'])

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X = scaler.fit_transform(X)
test_X = scaler.transform(test_X)
x_scaled =X
x_scaled
# Out:
# array([[-0.15159698,  0.79807381, -0.08208976, ...,  1.00376594,
#          0.03654455, -1.12495276],
#        [-1.07987451,  0.79807381,  0.04798489, ...,  0.21985964,
#          8.72042037, -1.12495276],
#        [-0.15159698,  0.79807381, -0.28428571, ..., -0.70037819,
#         -0.30900154,  0.88892622],
#        ...,
#        [ 1.70495808,  0.79807381, -0.36117713, ...,  0.73110288,
#         -0.3115662 , -1.12495276],
#        [-0.15159698, -1.25301694, -0.42240549, ...,  1.17418035,
#         -0.7339668 ,  0.88892622],
#        [ 1.70495808,  0.79807381, -0.26577482, ..., -0.70037819,
#         -0.36662105, -1.12495276]])

# %% [markdown]
# <h4 style="text-align: left; font-family: Arial; color: #3399ff;">
# Let's proceed with data splitting and model training for final evaluation.
# </h4>

# %%
import xgboost as xgb
model = xgb.XGBClassifier()
param_grid = {
    'n_estimators': [100, 300, 500], 
    'learning_rate': [0.01, 0.1, 0.3],  
    'max_depth': [3, 5, 8, 10],
}

grid_search = GridSearchCV(estimator=model, param_grid=param_grid, scoring='f1', cv=3)
grid_search.fit(x_scaled, y)
best_params = grid_search.best_params_
best_f1 = grid_search.best_score_

print("Best Parameters:", best_params)
print("Best F1 Score:", best_f1)
best_model = grid_search.best_estimator_
# Out:
# Best Parameters: {'learning_rate': 0.3, 'max_depth': 8, 'n_estimators': 500}
# Best F1 Score: 0.9454899890062144

# %%
predicted_test_data =best_model.predict(test_X)
classification_rep_val = classification_report(y_test, predicted_test_data)

# %% [markdown]
# <h4 style="text-align: left; font-family: Arial; color: #3399ff;">
# Our model performs exceptionally well, as evidenced by the confusion matrix. This suggests a high degree of reliability.
# </h4>

# %%
print(classification_rep_val)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      8538
#            1       0.98      0.92      0.95      1564
#
#     accuracy                           0.99     10102
#    macro avg       0.98      0.96      0.97     10102
# weighted avg       0.99      0.99      0.99     10102

# %%
from sklearn.metrics import confusion_matrix
conf_matrix = confusion_matrix(y_test, predicted_test_data)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", 
            xticklabels=sorted(np.unique(y_test)), 
            yticklabels=sorted(np.unique(y_test)))
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# <h4 style="text-align: left; font-family: Arial; color: #3399ff;">
# Analyzing feature importances to determine which features contribute most to model predictions
# </h4>

# %%
feature_names = ['ReserveStatus','Male','Price','CouponDiscount','Domestic','Vehicle','VehicleClass','From','To','TimeDifference_minutes','TripReason']
x_scaled = pd.DataFrame(x_scaled, columns=feature_names)

# %%
feature_names = x_scaled.columns if isinstance(x_scaled, pd.DataFrame) else [f'feature_{i}' for i in range(x_scaled.shape[1])]
feature_importances = best_model.feature_importances_
importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importances})
importance_df = importance_df.sort_values(by='Importance', ascending=False)
print(importance_df)
plt.figure(figsize=(10, 6))
plt.barh(importance_df['Feature'], importance_df['Importance'])
plt.xlabel('Feature Importance')
plt.ylabel('Feature')
plt.title('Feature Importances')
plt.gca().invert_yaxis()
plt.show()
# Out:
#                    Feature  Importance
# 0            ReserveStatus    0.923298
# 6             VehicleClass    0.038359
# 2                    Price    0.016137
# 5                  Vehicle    0.013760
# 4                 Domestic    0.001669
# 10              TripReason    0.001329
# 3           CouponDiscount    0.001272
# 8                       To    0.001189
# 9   TimeDifference_minutes    0.001123
# 7                     From    0.001116
# 1                     Male    0.000748
